# %%
import rdflib

# create a Graph
g = rdflib.Graph()

# parse in an RDF file hosted on the Internet
result = g.parse("pg30918 - Copy.rdf")

# loop through each triple in the graph (subj, pred, obj)
for subj, pred, obj in g:
    # check if there is at least one triple in the Graph
    if (subj, pred, obj) not in g:
       raise Exception("It better be!")

# print the number of "triples" in the Graph
print("graph has {} statements.".format(len(g)))
# prints graph has 86 statements.

# print out the entire Graph in the RDF Turtle format
print(g.serialize(format="turtle").decode("utf-8"))
# Out:
# graph has 148 statements.
# @prefix cc: <http://web.resource.org/cc/> .
# @prefix dcam: <http://purl.org/dc/dcam/> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix pgterms: <http://www.gutenberg.org/2009/pgterms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://www.gutenberg.org/> a cc:Work ;
#     cc:license <https://creativecommons.org/publicdomain/zero/1.0/> ;
#     rdfs:comment """Archives containing the RDF files for *all* our books can be downloaded at
#             https://www.gutenberg.org/wiki/Gutenberg:Feeds#The_Complete_Project_Gutenberg_Catalog""" .
#
# <http://en.wikipedia.org/wiki/Alphonse_de_Lamartine> dcterms:description "en. wikipedia" .
#
# <http://fr.wikipedia.org/wiki/Alphonse_de_Lamartine> dcterms:description "fr.wikipedia" .
#
# <http://www.gutenberg.org/2009/agents/4781> a pgterms:agent ;
#     pgterms:alias "De Lamartine, Alphonse",
#         "Lamartine de Prat, Alphonse-Marie-Louis de",
#         "Lamartine, Alphonse Marie Louis de" ;
#     pgterms:birthdate 1790 ;
#     pgterms:deathdate 1869 ;
#     pgterms:name "Lamartine, Alphonse de" ;
#     pgterms:webpage <http://en.wikipedia.org/wiki/Alphonse_de_Lamartine>,
#         <http://fr.wikipedia.org/wiki/Alphonse_de_Lamartine> .
#
# <https://www.gutenberg.org/cache/epub/30918/pg30918.cover.medium.jpg> a pgterms:file ;
#     dcterms:extent 15099 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "image/jpeg"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2020-10-15T06:39:39.422171"^^xsd:dateTime .
#
# <https://www.gutenberg.org/cache/epub/30918/pg30918.cover.small.jpg> a pgterms:file ;
#     dcterms:extent 3587 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "image/jpeg"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2020-10-15T06:39:39.275162"^^xsd:dateTime .
#
# <https://www.gutenberg.org/ebooks/30918.epub.images> a pgterms:file ;
#     dcterms:extent 287331 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "application/epub+zip"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2020-10-15T06:39:35.813231"^^xsd:dateTime .
#
# <https://www.gutenberg.org/ebooks/30918.epub.noimages> a pgterms:file ;
#     dcterms:extent 268370 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "application/epub+zip"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2020-10-15T06:39:36.425197"^^xsd:dateTime .
#
# <https://www.gutenberg.org/ebooks/30918.kindle.images> a pgterms:file ;
#     dcterms:extent 1115693 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "application/x-mobipocket-ebook"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2020-10-15T06:39:37.780181"^^xsd:dateTime .
#
# <https://www.gutenberg.org/ebooks/30918.kindle.noimages> a pgterms:file ;
#     dcterms:extent 1078128 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "application/x-mobipocket-ebook"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2020-10-15T06:39:39.129166"^^xsd:dateTime .
#
# <https://www.gutenberg.org/ebooks/30918.rdf> a pgterms:file ;
#     dcterms:extent 14428 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "application/rdf+xml"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2020-11-12T05:27:29.141694"^^xsd:dateTime .
#
# <https://www.gutenberg.org/ebooks/30918.txt.utf-8> a pgterms:file ;
#     dcterms:extent 491662 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "text/plain"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2020-10-15T06:39:34.997240"^^xsd:dateTime .
#
# <https://www.gutenberg.org/files/30918/30918-8.txt> a pgterms:file ;
#     dcterms:extent 478805 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "text/plain; charset=iso-8859-1"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2010-01-10T12:35:32"^^xsd:dateTime .
#
# <https://www.gutenberg.org/files/30918/30918-8.zip> a pgterms:file ;
#     dcterms:extent 186645 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "application/zip"^^dcterms:IMT ],
#         [ dcam:memberOf dcterms:IMT ;
#             rdf:value "text/plain; charset=iso-8859-1"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2010-01-10T12:35:34"^^xsd:dateTime .
#
# <https://www.gutenberg.org/files/30918/30918-h.zip> a pgterms:file ;
#     dcterms:extent 215899 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "application/zip"^^dcterms:IMT ],
#         [ dcam:memberOf dcterms:IMT ;
#             rdf:value "text/html; charset=iso-8859-1"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2010-01-10T12:35:36"^^xsd:dateTime .
#
# <https://www.gutenberg.org/files/30918/30918-h/30918-h.htm> a pgterms:file ;
#     dcterms:extent 525045 ;
#     dcterms:format [ dcam:memberOf dcterms:IMT ;
#             rdf:value "text/html; charset=iso-8859-1"^^dcterms:IMT ] ;
#     dcterms:isFormatOf <http://www.gutenberg.org/ebooks/30918> ;
#     dcterms:modified "2010-01-10T12:35:34"^^xsd:dateTime .
#
# <http://www.gutenberg.org/ebooks/30918> a pgterms:ebook ;
#     dcterms:creator <http://www.gutenberg.org/2009/agents/4781> ;
#     dcterms:hasFormat <https://www.gutenberg.org/cache/epub/30918/pg30918.cover.medium.jpg>,
#         <https://www.gutenberg.org/cache/epub/30918/pg30918.cover.small.jpg>,
#         <https://www.gutenberg.org/ebooks/30918.epub.images>,
#         <https://www.gutenberg.org/ebooks/30918.epub.noimages>,
#         <https://www.gutenberg.org/ebooks/30918.kindle.images>,
#         <https://www.gutenberg.org/ebooks/30918.kindle.noimages>,
#         <https://www.gutenberg.org/ebooks/30918.rdf>,
#         <https://www.gutenberg.org/ebooks/30918.txt.utf-8>,
#         <https://www.gutenberg.org/files/30918/30918-8.txt>,
#         <https://www.gutenberg.org/files/30918/30918-8.zip>,
#         <https://www.gutenberg.org/files/30918/30918-h.zip>,
#         <https://www.gutenberg.org/files/30918/30918-h/30918-h.htm> ;
#     dcterms:issued "2010-01-10"^^xsd:date ;
#     dcterms:language [ rdf:value "fr"^^dcterms:RFC4646 ] ;
#     dcterms:license <http://www.gutenberg.org/license> ;
#     dcterms:publisher "Project Gutenberg" ;
#     dcterms:rights "Public domain in the USA." ;
#     dcterms:subject [ dcam:memberOf dcterms:LCSH ;
#             rdf:value "French literature -- History and criticism" ],
#         [ dcam:memberOf dcterms:LCC ;
#             rdf:value "PN" ],
#         [ dcam:memberOf dcterms:LCSH ;
#             rdf:value "France -- Politics and government -- 1789-1900" ],
#         [ dcam:memberOf dcterms:LCSH ;
#             rdf:value "Literature -- History and criticism" ] ;
#     dcterms:title "Cours familier de Littérature - Volume 05" ;
#     dcterms:type [ dcam:memberOf dcterms:DCMIType ;
#             rdf:value "Text" ] ;
#     pgterms:bookshelf [ dcam:memberOf pgterms:Bookshelf ;
#             rdf:value "FR Littérature" ],
#         [ dcam:memberOf pgterms:Bookshelf ;
#             rdf:value "France" ] ;
#     pgterms:downloads 12 ;
#     pgterms:marc010 "32003460" .

# %%
ss = []
pp = []
oo = []

for i in g.subject_objects():
    print(i)
# Out:
# .term.Literal('fr.wikipedia'))
# (rdflib.term.URIRef('https://www.gutenberg.org/cache/epub/30918/pg30918.cover.small.jpg'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h/30918-h.htm'), rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'))
# (rdflib.term.BNode('N37c2a6861a5647dcb0605441193f9297'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.URIRef('http://www.gutenberg.org/2009/agents/4781'), rdflib.term.URIRef('http://fr.wikipedia.org/wiki/Alphonse_de_Lamartine'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.BNode('N5597484e75e549269f1b3ac0099b4f80'))
# (rdflib.term.BNode('N05580e435a014ffdad15054f8e84d66f'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.rdf'), rdflib.term.Literal('14428', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.rdf'), rdflib.term.BNode('Ne2daf6fd633c4c84972bf6a984a5bc0b'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.BNode('Ncaf3750e505d4dae963a250d87f4cbc6'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-8.txt'), rdflib.term.Literal('2010-01-10T12:35:32', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.BNode('Nd7ebdbfa9a864eee81baebb3d84a1d76'), rdflib.term.Literal('application/epub+zip', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h/30918-h.htm'), rdflib.term.BNode('Ndf4eb8fc9feb4157a815da4f6c98cea2'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.txt.utf-8'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.BNode('N6fe321ff89d748c2aecee7c281cf4fb8'))
# (rdflib.term.BNode('Ncaf3750e505d4dae963a250d87f4cbc6'), rdflib.term.URIRef('http://purl.org/dc/terms/DCMIType'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.BNode('N3fc4c61977764c9f8ffa0db1035f4189'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('http://www.gutenberg.org/license'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.BNode('N2bebabf83598429bab458e3cc3da7fe3'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.txt.utf-8'), rdflib.term.BNode('N4e0061a2330f4c188b566f55e778eb86'))
# (rdflib.term.BNode('Nd7ebdbfa9a864eee81baebb3d84a1d76'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.BNode('N1449daffeec840e281199a17878f1adf'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('https://www.gutenberg.org/cache/epub/30918/pg30918.cover.small.jpg'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-8.zip'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.txt.utf-8'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.noimages'), rdflib.term.Literal('2020-10-15T06:39:39.129166', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.BNode('N4b1b1fe1d94946d080c69b99750e1f12'), rdflib.term.Literal('France'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.images'))
# (rdflib.term.URIRef('https://www.gutenberg.org/cache/epub/30918/pg30918.cover.small.jpg'), rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'))
# (rdflib.term.BNode('N227b8c41cd42449ab8bd3478cac8ac5a'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.noimages'), rdflib.term.BNode('N2f85dbb78cbf4a0d9a030ab314c2b3bc'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.noimages'), rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'))
# (rdflib.term.BNode('N2167b6e3b6ef454592a2e617d2637d44'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h.zip'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.BNode('N1bd0b892512940249e1b2d1342c3c43d'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.images'), rdflib.term.BNode('N2167b6e3b6ef454592a2e617d2637d44'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.txt.utf-8'), rdflib.term.Literal('2020-10-15T06:39:34.997240', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.noimages'), rdflib.term.BNode('Nd7ebdbfa9a864eee81baebb3d84a1d76'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h/30918-h.htm'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.Literal('2010-01-10', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date')))
# (rdflib.term.BNode('N62415f037ce4482ca1b98c0535272a41'), rdflib.term.URIRef('http://purl.org/dc/terms/LCC'))
# (rdflib.term.URIRef('http://www.gutenberg.org/2009/agents/4781'), rdflib.term.Literal('Lamartine, Alphonse Marie Louis de'))
# (rdflib.term.URIRef('http://en.wikipedia.org/wiki/Alphonse_de_Lamartine'), rdflib.term.Literal('en. wikipedia'))
# (rdflib.term.BNode('Ne2daf6fd633c4c84972bf6a984a5bc0b'), rdflib.term.Literal('application/rdf+xml', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.Literal('Public domain in the USA.'))
# (rdflib.term.BNode('N2167b6e3b6ef454592a2e617d2637d44'), rdflib.term.Literal('application/epub+zip', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.noimages'), rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'))
# (rdflib.term.BNode('N5597484e75e549269f1b3ac0099b4f80'), rdflib.term.Literal('fr', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/RFC4646')))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.BNode('Na3bdd70a191f41f7a8421ef10d9ba238'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.Literal('12', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N2bebabf83598429bab458e3cc3da7fe3'), rdflib.term.Literal('French literature -- History and criticism'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.Literal('Cours familier de Littérature - Volume 05'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.noimages'))
# (rdflib.term.BNode('Ndf4eb8fc9feb4157a815da4f6c98cea2'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.BNode('N37c2a6861a5647dcb0605441193f9297'), rdflib.term.Literal('image/jpeg', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-8.txt'), rdflib.term.BNode('N1449daffeec840e281199a17878f1adf'))
# (rdflib.term.BNode('N05580e435a014ffdad15054f8e84d66f'), rdflib.term.Literal('application/zip', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.noimages'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-8.txt'), rdflib.term.Literal('478805', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h.zip'))
# (rdflib.term.BNode('N4e0061a2330f4c188b566f55e778eb86'), rdflib.term.Literal('text/plain', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.rdf'), rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.txt.utf-8'), rdflib.term.Literal('491662', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd495260ca5184b3eaed4deb240a7d77a'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-8.zip'), rdflib.term.BNode('N227b8c41cd42449ab8bd3478cac8ac5a'))
# (rdflib.term.URIRef('http://www.gutenberg.org/'), rdflib.term.URIRef('https://creativecommons.org/publicdomain/zero/1.0/'))
# (rdflib.term.BNode('Ne2daf6fd633c4c84972bf6a984a5bc0b'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.URIRef('http://www.gutenberg.org/2009/agents/4781'), rdflib.term.Literal('Lamartine, Alphonse de'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.Literal('32003460'))
# (rdflib.term.URIRef('http://www.gutenberg.org/2009/agents/4781'), rdflib.term.Literal('De Lamartine, Alphonse'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.BNode('N4b1b1fe1d94946d080c69b99750e1f12'))
# (rdflib.term.BNode('Ncaf3750e505d4dae963a250d87f4cbc6'), rdflib.term.Literal('Text'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.rdf'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.images'), rdflib.term.Literal('287331', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.images'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.noimages'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.BNode('Na9b8d2cf40aa4d0d85dd05f4e1cd29f7'), rdflib.term.Literal('image/jpeg', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.images'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.URIRef('https://www.gutenberg.org/cache/epub/30918/pg30918.cover.small.jpg'), rdflib.term.BNode('Na9b8d2cf40aa4d0d85dd05f4e1cd29f7'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-8.zip'), rdflib.term.BNode('Nd495260ca5184b3eaed4deb240a7d77a'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.txt.utf-8'), rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h/30918-h.htm'), rdflib.term.Literal('2010-01-10T12:35:34', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.BNode('N2f85dbb78cbf4a0d9a030ab314c2b3bc'), rdflib.term.Literal('application/x-mobipocket-ebook', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-8.zip'))
# (rdflib.term.URIRef('https://www.gutenberg.org/cache/epub/30918/pg30918.cover.medium.jpg'), rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.images'), rdflib.term.BNode('Ne364b713fcd04ce09d21d35a82591ec4'))
# (rdflib.term.BNode('Na3bdd70a191f41f7a8421ef10d9ba238'), rdflib.term.Literal('Literature -- History and criticism'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h.zip'), rdflib.term.BNode('N1bd0b892512940249e1b2d1342c3c43d'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.images'))
# (rdflib.term.URIRef('http://www.gutenberg.org/'), rdflib.term.Literal('Archives containing the RDF files for *all* our books can be downloaded at\n            https://www.gutenberg.org/wiki/Gutenberg:Feeds#The_Complete_Project_Gutenberg_Catalog'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-8.zip'), rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'))
# (rdflib.term.BNode('N6fe321ff89d748c2aecee7c281cf4fb8'), rdflib.term.Literal('France -- Politics and government -- 1789-1900'))
# (rdflib.term.URIRef('https://www.gutenberg.org/cache/epub/30918/pg30918.cover.small.jpg'), rdflib.term.Literal('2020-10-15T06:39:39.275162', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.BNode('N6fe321ff89d748c2aecee7c281cf4fb8'), rdflib.term.URIRef('http://purl.org/dc/terms/LCSH'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.Literal('Project Gutenberg'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.rdf'), rdflib.term.Literal('2020-11-12T05:27:29.141694', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.images'), rdflib.term.Literal('1115693', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h.zip'), rdflib.term.BNode('N05580e435a014ffdad15054f8e84d66f'))
# (rdflib.term.BNode('N2f85dbb78cbf4a0d9a030ab314c2b3bc'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.BNode('Ne364b713fcd04ce09d21d35a82591ec4'), rdflib.term.Literal('application/x-mobipocket-ebook', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.images'), rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.noimages'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.BNode('N62415f037ce4482ca1b98c0535272a41'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h.zip'), rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'))
# (rdflib.term.URIRef('https://www.gutenberg.org/cache/epub/30918/pg30918.cover.medium.jpg'), rdflib.term.BNode('N37c2a6861a5647dcb0605441193f9297'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.images'), rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.images'), rdflib.term.Literal('2020-10-15T06:39:37.780181', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-8.zip'), rdflib.term.Literal('2010-01-10T12:35:34', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h/30918-h.htm'), rdflib.term.Literal('525045', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-8.zip'), rdflib.term.Literal('186645', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N4e0061a2330f4c188b566f55e778eb86'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.noimages'), rdflib.term.Literal('268370', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.rdf'))
# (rdflib.term.BNode('N1449daffeec840e281199a17878f1adf'), rdflib.term.Literal('text/plain; charset=iso-8859-1', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('https://www.gutenberg.org/cache/epub/30918/pg30918.cover.small.jpg'), rdflib.term.Literal('3587', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.noimages'), rdflib.term.Literal('2020-10-15T06:39:36.425197', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('http://www.gutenberg.org/2009/agents/4781'), rdflib.term.Literal('Lamartine de Prat, Alphonse-Marie-Louis de'))
# (rdflib.term.BNode('N62415f037ce4482ca1b98c0535272a41'), rdflib.term.Literal('PN'))
# (rdflib.term.BNode('Ne364b713fcd04ce09d21d35a82591ec4'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.URIRef('http://www.gutenberg.org/2009/agents/4781'), rdflib.term.Literal('1790', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.gutenberg.org/2009/agents/4781'), rdflib.term.URIRef('http://en.wikipedia.org/wiki/Alphonse_de_Lamartine'))
# (rdflib.term.BNode('N2bebabf83598429bab458e3cc3da7fe3'), rdflib.term.URIRef('http://purl.org/dc/terms/LCSH'))
# (rdflib.term.BNode('N4b1b1fe1d94946d080c69b99750e1f12'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/Bookshelf'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h.zip'), rdflib.term.Literal('2010-01-10T12:35:36', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.BNode('N3fc4c61977764c9f8ffa0db1035f4189'), rdflib.term.Literal('FR Littérature'))
# (rdflib.term.BNode('Na9b8d2cf40aa4d0d85dd05f4e1cd29f7'), rdflib.term.URIRef('http://purl.org/dc/terms/IMT'))
# (rdflib.term.URIRef('http://www.gutenberg.org/2009/agents/4781'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/agent'))
# (rdflib.term.URIRef('http://www.gutenberg.org/2009/agents/4781'), rdflib.term.Literal('1869', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.epub.images'), rdflib.term.Literal('2020-10-15T06:39:35.813231', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h/30918-h.htm'))
# (rdflib.term.URIRef('https://www.gutenberg.org/cache/epub/30918/pg30918.cover.medium.jpg'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-8.txt'), rdflib.term.URIRef('http://www.gutenberg.org/2009/pgterms/file'))
# (rdflib.term.URIRef('https://www.gutenberg.org/files/30918/30918-h.zip'), rdflib.term.Literal('215899', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://www.gutenberg.org/cache/epub/30918/pg30918.cover.medium.jpg'), rdflib.term.Literal('2020-10-15T06:39:39.422171', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('http://www.gutenberg.org/ebooks/30918'), rdflib.term.URIRef('http://www.gutenberg.org/2009/agents/4781'))
# (rdflib.term.BNode('N1bd0b892512940249e1b2d1342c3c43d'), rdflib.term.Literal('text/html; charset=iso-8859-1', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('https://www.gutenberg.org/ebooks/30918.kindle.noimages'), rdflib.term.Literal('1078128', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.gutenberg.org/'), rdflib.term.URIRef('http://web.resource.org/cc/Work'))
# (rdflib.term.BNode('N227b8c41cd42449ab8bd3478cac8ac5a'), rdflib.term.Literal('application/zip', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
# (rdflib.term.URIRef('https://www.gutenberg.org/cache/epub/30918/pg30918.cover.medium.jpg'), rdflib.term.Literal('15099', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd495260ca5184b3eaed4deb240a7d77a'), rdflib.term.Literal('text/plain; charset=iso-8859-1', datatype=rdflib.term.URIRef('http://purl.org/dc/terms/IMT')))
